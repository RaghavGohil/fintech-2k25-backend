# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imblearn) (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tilak devi\anaconda3\envs\main\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# ----------------------------
# 1. Load the Dataset (Data is already cleaned)
# ----------------------------
file_path = "million2.csv"  # Adjust the path if needed
df = pd.read_csv(file_path)

# ----------------------------
# 2. Define Features and Target
# ----------------------------
target_column = "Is Fraud?"
X = df.drop(columns=[target_column])
# Convert target labels from 1 and 2 to 0 and 1 for binary classification
y = df[target_column].astype(int) - 1

# ----------------------------
# 3. Setup 10-Fold Stratified Cross-Validation with TQDM
# ----------------------------
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold = 1

for train_index, test_index in tqdm(skf.split(X, y), total=10, desc="CV Folds"):
    # Split the data into training and testing sets for this fold
    X_train = X.iloc[train_index]
    X_test = X.iloc[test_index]
    y_train = y.iloc[train_index]
    y_test = y.iloc[test_index]
    
    # ----------------------------
    # 4. Apply SMOTE for Class Balancing on Training Data
    # ----------------------------
    smote = SMOTE(random_state=42)
    X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)
    
    # ----------------------------
    # 5. Initialize and Train XGBoost with GPU Acceleration
    # ----------------------------
    xgb_clf = XGBClassifier(
        tree_method='gpu_hist',      # Use GPU-accelerated tree building
        predictor='gpu_predictor',   # Use GPU for predictions
        random_state=42,
        use_label_encoder=False,      # Avoid warning regarding label encoder
        eval_metric='logloss'         # Evaluation metric for binary classification
    )
    
    xgb_clf.fit(X_train_bal, y_train_bal)
    
    # ----------------------------
    # 6. Make Predictions on the Test Set
    # ----------------------------
    y_pred = xgb_clf.predict(X_test)
    
    # ----------------------------
    # 7. Evaluate: Classification Report and Confusion Matrix
    # ----------------------------
    print(f"\n--- Classification Report for Fold {fold} ---")
    print(classification_report(y_test, y_pred))
    
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for Fold {fold}:")
    print(cm)
    
    # Plot confusion matrix as a heatmap
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - Fold {fold}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
    
    fold += 1
# Out:
# CV Folds:   0%|          | 0/10 [00:00<?, ?it/s]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:39:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:39:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:39:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:39:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 1 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97025
#            1       0.58      0.86      0.69      2975
#
#     accuracy                           0.98    100000
#    macro avg       0.79      0.92      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 1:
# [[95196  1829]
#  [  426  2549]]
# CV Folds:  10%|█         | 1/10 [00:06<00:54,  6.08s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 2 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97025
#            1       0.58      0.87      0.69      2975
#
#     accuracy                           0.98    100000
#    macro avg       0.79      0.93      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 2:
# [[95116  1909]
#  [  374  2601]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  20%|██        | 2/10 [00:09<00:37,  4.69s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 3 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97025
#            1       0.56      0.87      0.68      2975
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.93      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 3:
# [[95015  2010]
#  [  381  2594]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  30%|███       | 3/10 [00:13<00:29,  4.15s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 4 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.56      0.87      0.68      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.92      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 4:
# [[95012  2012]
#  [  389  2587]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  40%|████      | 4/10 [00:17<00:24,  4.01s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 5 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.56      0.87      0.68      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.92      0.83    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 5:
# [[95018  2006]
#  [  397  2579]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  50%|█████     | 5/10 [00:20<00:19,  3.89s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 6 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.56      0.88      0.68      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.93      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 6:
# [[94977  2047]
#  [  366  2610]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  60%|██████    | 6/10 [00:24<00:15,  3.83s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 7 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.56      0.87      0.68      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.92      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 7:
# [[95031  1993]
#  [  391  2585]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds:  70%|███████   | 7/10 [00:28<00:11,  3.83s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 8 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.55      0.86      0.67      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.77      0.92      0.83    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 8:
# [[94966  2058]
#  [  427  2549]]
# CV Folds:  80%|████████  | 8/10 [00:32<00:07,  3.83s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 9 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.55      0.86      0.67      2976
#
#     accuracy                           0.97    100000
#    macro avg       0.77      0.92      0.83    100000
# weighted avg       0.98      0.97      0.98    100000
#
# Confusion Matrix for Fold 9:
# [[94926  2098]
#  [  412  2564]]
# CV Folds:  90%|█████████ | 9/10 [00:36<00:03,  3.84s/it]c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# --- Classification Report for Fold 10 ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     97024
#            1       0.57      0.86      0.69      2976
#
#     accuracy                           0.98    100000
#    macro avg       0.78      0.92      0.84    100000
# weighted avg       0.98      0.98      0.98    100000
#
# Confusion Matrix for Fold 10:
# [[95117  1907]
#  [  407  2569]]
# c:\Users\Tilak Devi\anaconda3\envs\main\lib\site-packages\xgboost\core.py:158: UserWarning: [15:40:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# CV Folds: 100%|██████████| 10/10 [00:39<00:00,  3.96s/it]
